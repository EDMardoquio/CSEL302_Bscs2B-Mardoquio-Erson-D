# %% [markdown]
# <a href="https://colab.research.google.com/github/EDMardoquio/CSEL302_Bscs2B-Mardoquio-Erson-D/blob/main/LInear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 IMPORTS
#
#
# ```
# # This is formatted as code
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# 2. Generating Ramdom Data

# %%
num_points = 50
x = np.random.randint(0,100,num_points)
y = 2 * x + np.random.normal(0,10,num_points)

# %% [markdown]
# 3. Creating DataFrame and Saving To Csv

# %%
data.to_csv('Lesson_4_student_grades_dataset.csv',index=False)
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0373be82385a> in <cell line: 1>()
# ----> 1 data.to_csv('Lesson_4_student_grades_dataset.csv',index=False)
#       2 print(data.head())
#
# NameError: name 'data' is not defined

# %% [markdown]
# 4. Visualizing the Data

# %%
plt.scatter(data['X'],data['Y'])
plt.xlabel('Independent Variable {x}')
plt.ylabel('dependent Variable {y}')
plt.title('Scatter plot of Data')
plt.show()

# %% [markdown]
# 5. Preparing Data for Modeling

# %%
x = data[['X']]
y = data[['Y']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-567a3fc50afb> in <cell line: 1>()
# ----> 1 x = data[['X']]
#       2 y = data[['Y']]
#       3
#
# NameError: name 'data' is not defined

# %% [markdown]
# 6. Fitting the Linear Regression Model

# %%
model = LinearRegression()

model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# 7. Getting model Coefficient

# %%
slope = model.coef_[0]

intercept = model.intercept_

print('slope',slope)
print('Intercept',intercept)
# Out:
# slope [2.04359333]
# Intercept [-2.64218351]

# %% [markdown]
# 8. Visualizing the Linear Regression Line

# %%
plt.scatter(x,y)
plt.plot(x,model.predict(x),color=('red'))
plt.xlabel('Independent Variable {x}')
plt.ylabel('dependent Variable {y}')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# 9 Making Prediction

# %%
new_x = [[np.random.randint(100,200)]]

predicted_y = model.predict(new_x)

print('Value of x: ',new_x)
print('Predicted Value of y: ',predicted_y)
# Out:
# Value of x:  [[195]]
# Predicted Value of y:  [[395.85851583]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
